# %% [markdown]
# <a href="https://colab.research.google.com/github/OMGarad/BERT-Project/blob/main/Keyword_Extraction_From_Spanish_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install keybert
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/cd/12/b72f6ce98984157cb0db83baf56a7c8f9eb4df4494d671234dccb630f8a3/keybert-0.4.0.tar.gz
# ...
#      |████████████████████████████████| 92kB 2.9MB/s
# ...
#      |████████████████████████████████| 215kB 15.1MB/s
# ...
#      |████████████████████████████████| 2.5MB 43.6MB/s
# ...
#      |████████████████████████████████| 1.2MB 45.4MB/s
# ...
#      |████████████████████████████████| 51kB 5.4MB/s
# ...
#      |████████████████████████████████| 901kB 37.6MB/s
# ...
#      |████████████████████████████████| 3.3MB 35.9MB/s
# ...
#   Created wheel for keybert: filename=keybert-0.4.0-cp37-none-any.whl size=20359 sha256=6e8c4d6f84c440747a88f3043e2a29e810b7d0fd2d635d903ec441528ad3dd5d
#   Stored in directory: /root/.cache/pip/wheels/03/5d/47/3043be54833aa892612970b46edc8cb1a3b6d4e74a53efb316
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.0.0-cp37-none-any.whl size=126711 sha256=ee6aa7285949ed31767224973f6e830edfbaf0c930255099757fbe1279562531
# ...

# %%
from keybert import KeyBERT

doc = """
         En aprendizaje automático y minería de datos, el aprendizaje supervisado es una técnica para deducir una función a partir de datos de entrenamiento.
         Los datos de entrenamiento consisten de pares de objetos (normalmente vectores): una componente del par son los datos de entrada y el otro, los resultados deseados.
         La salida de la función puede ser un valor numérico (como en los problemas de regresión) o una etiqueta de clase (como en los de clasificación).
         El objetivo del aprendizaje supervisado es el de crear una función capaz de predecir el valor correspondiente a cualquier objeto de entrada válida después de haber visto una serie de ejemplos, los datos de entrenamiento.
         Para ello, tiene que generalizar a partir de los datos presentados a las situaciones no vistas previamente.
      """
kw_model = KeyBERT('paraphrase-multilingual-MiniLM-L12-v2')
keywords = kw_model.extract_keywords(doc)

# %%
print(keywords)
# Out:
# [('aprendizaje', 0.6024), ('entrenamiento', 0.5165), ('clasificación', 0.3991), ('supervisado', 0.3963), ('datos', 0.3929)]
