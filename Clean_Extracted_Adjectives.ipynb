# %%
file= open('Translated_Adjectives.txt', 'r', encoding='utf-8')
input=file.readlines()

# %%
print(type(input))
# Out:
# <class 'list'>

# %%
for sentences in input:
    if sentences=='\n':
        input.remove(sentences)

# %%
print(input)
# Out:
# ['sprouted\n', 'eyed\n', 'english\n', 'thumb impression\n', 'Angoori\n', 'anjora\n', 'Anjori\n', 'Andua\n', 'eggshell\n', 'antara\n', 'blind\n', 'darkness\n', 'darkness\n', 'blind\n', 'darkness\n', 'notable\n', 'numeric\n', 'Ankit\n', 'sprouted\n', 'Germinated\n', 'Ankhuaaya\n', 'Angaz\n', 'brawl\n', 'limbed\n', 'part\n', 'tunic\n', 'english\n', 'limbless\n', 'body\n', 'confession\n', 'adopted\n', 'custodial\n', 'Angoori\n', 'Angolan\n', 'Angolan\n', 'english\n', 'English\n', 'regional\n', 'regional\n', 'seedless\n', 'anjaha\n', 'Anjora\n', 'Anjori\n', 'ant-st\n', 'Antsant\n', 'A cheat\n', 'Antibaaz\n', 'ninety nine\n', 'ninety nine\n', 'ninety-nine\n', 'eighteenth\n', 'eighteen\n', 'under-bund\n', 'egg\n', 'egg bund\n', 'oval\n', 'egg-like\n', 'eggshell\n', 'in the end\n', 'underlying\n', 'Antkarari\n', 'intimate\n', 'insider\n', 'intuitive\n', 'interstate_level\n', 'interregional\n', 'interprovincial\n', 'interstate\n', 'International\n', 'Antara\n', 'introverted\n', 'inmate\n', 't
# ...

# %%
print(len(input))
# Out:
# 12028

# %%
l=[]
for sentences in input:
    l.append(sentences)

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
print(l)
# Out:
# ['sprouted\n', 'eyed\n', 'english\n', 'thumb impression\n', 'Angoori\n', 'anjora\n', 'Anjori\n', 'Andua\n', 'eggshell\n', 'antara\n', 'blind\n', 'darkness\n', 'darkness\n', 'blind\n', 'darkness\n', 'notable\n', 'numeric\n', 'Ankit\n', 'sprouted\n', 'Germinated\n', 'Ankhuaaya\n', 'Angaz\n', 'brawl\n', 'limbed\n', 'part\n', 'tunic\n', 'english\n', 'limbless\n', 'body\n', 'confession\n', 'adopted\n', 'custodial\n', 'Angoori\n', 'Angolan\n', 'Angolan\n', 'english\n', 'English\n', 'regional\n', 'regional\n', 'seedless\n', 'anjaha\n', 'Anjora\n', 'Anjori\n', 'ant-st\n', 'Antsant\n', 'A cheat\n', 'Antibaaz\n', 'ninety nine\n', 'ninety nine\n', 'ninety-nine\n', 'eighteenth\n', 'eighteen\n', 'under-bund\n', 'egg\n', 'egg bund\n', 'oval\n', 'egg-like\n', 'eggshell\n', 'in the end\n', 'underlying\n', 'Antkarari\n', 'intimate\n', 'insider\n', 'intuitive\n', 'interstate_level\n', 'interregional\n', 'interprovincial\n', 'interstate\n', 'International\n', 'Antara\n', 'introverted\n', 'inmate\n', 't
# ...

# %%
print(len(l))
# Out:
# 12028

# %%
file2= open("Cleaned_Translated_Adjectives.txt", "w", encoding='utf-8')
input2=file2.writelines(l)
