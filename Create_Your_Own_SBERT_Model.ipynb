# %% [markdown]
# <a href="https://colab.research.google.com/github/OMGarad/BERT-Project/blob/main/Create_Your_Own_SBERT_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U sentence-transformers
# Out:
# ...
#      |████████████████████████████████| 85 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 2.6 MB 41.4 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 45.9 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 895 kB 17.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 40.4 MB/s
# ...
#      |████████████████████████████████| 636 kB 66.6 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.0.0-py3-none-any.whl size=126710 sha256=c568e779fde22ecd3cb3e7c55f564aabe05cedc54971f7843029176934efa1df
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/0f/faafd427f705c4b012274ba60d9a91d75830306811e1355293
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from sentence_transformers import SentenceTransformer, models
from torch import nn

model = SentenceTransformer('distilbert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.99k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/550 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/265M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/450 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from sentence_transformers import InputExample,  losses
from torch.utils.data import DataLoader

# %%
train_examples=[InputExample(texts=[ "Brahma is unborn"
, "ब्रह्म अजन्मा हैं"
 ], label=1.0 ), 
InputExample(texts=[ "It is considered inauspicious to cross the path of a cat"
, "बिल्ली का रास्ता काटना अशुभ माना जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "Let uninvited guests enter soon"
, "अप्रविष्ट अतिथियों को शीघ्र ही भीतर प्रवेश करने दिया जाय"
 ], label=1.0 ), 
InputExample(texts=[ "Kashi is a holy place for Hindus"
, "हिंदुओं के लिए काशी एक पवित्र स्थान है"
 ], label=1.0 ), 
InputExample(texts=[ "He goes to the pagoda every Monday"
, "वह प्रत्येक सोमवार को शिवालय जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "Religious belief that ghosts and spirits reside only in impure places"
, "धार्मिक मान्यता है कि भूत-प्रेत अपवित्र स्थानों पर ही निवास करते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Welcome Input Persons"
, "आगत व्यक्तियों का स्वागत करो"
 ], label=1.0 ), 
InputExample(texts=[ "Death is certain to be born"
, "जन्मे प्राणियों की मृत्यु निश्चित है"
 ], label=1.0 ), 
InputExample(texts=[ "Only through moral work we can uplift the society"
, "नैतिक कार्य के द्वारा ही हम समाज का उत्थान कर सकते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Tea produced in India is exported in large quantities to foreign countries"
, "भारत में उत्पन्न चाय अधिक मात्रा में विदेशों को निर्यात की जाती है"
 ], label=1.0 ), 
InputExample(texts=[ "Avoidance of wickedness"
, "दुश्चरित्रता से बचना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam's father is in the police so he shows arrogance"
, "श्याम के पिता पुलिस में हैं इसलिए वह हेकड़ी दिखाता है"
 ], label=1.0 ), 
InputExample(texts=[ "The British did a lot of atrocities on the Indian people"
, "भारतीय जनता पर अँग्रेज़ों ने बहुत ही अत्याचार किए"
 ], label=1.0 ), 
InputExample(texts=[ "Nowadays some scam is happening in every department"
, "आजकल हर विभाग में कुछ न कुछ घोटाला हो रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "There are six types of vitamins"
, "विटामिन छह प्रकार के होते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Truthfulness Makes a Man Great"
, "सच्चरित्रता मनुष्य को महान् बनाती है"
 ], label=1.0 ), 
InputExample(texts=[ "Your arbitrariness will not work here"
, "तुम्हारी मनमानी यहाँ नहीं चलेगी"
 ], label=1.0 ), 
InputExample(texts=[ "Wicked man always indulges in misdeeds"
, "दुष्ट व्यक्ति हमेशा दुष्कर्म में ही लिप्त रहता है"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam is a grain merchant"
, "श्याम अनाज का व्यापारी है"
 ], label=1.0 ), 
InputExample(texts=[ "Food is much more expensive in cities than in villages"
, "गाँव की अपेक्षा शहरों में खाद्य वस्तुएँ बहुत महँगी हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Ramu didn't get the job because he was inexperienced / He's inexperienced in this game"
, "अनुभवहीन होने के कारण रामू को नौकरी नहीं मिली / वह इस खेल में अनुभवहीन है"
 ], label=1.0 ), 
InputExample(texts=[ "Even untrained players played well"
, "अप्रवीण खिलाड़ियों ने भी अच्छे खेल का प्रदर्शन किया"
 ], label=1.0 ), 
InputExample(texts=[ "The manager fired ineligible persons from the institution"
, "प्रबंधक ने अयोग्य व्यक्तियों को संस्था से निकाल दिया"
 ], label=1.0 ), 
InputExample(texts=[ "To cure stomachache of Samarth Guru Ramdas, Guru Bhakt Shivaji brought the milk of a lioness"
, "समर्थ गुरु रामदास का पेट दर्द ठीक करने के लिए गुरु भक्त शिवाजी ने शेरनी का दूध लाया"
 ], label=1.0 ), 
InputExample(texts=[ "Even a novice can do this work"
, "यह काम नौसिखिया व्यक्ति भी कर सकता है"
 ], label=1.0 ), 
InputExample(texts=[ "Why do you act like clumsy people?"
, "तुम फूहड़ व्यक्तियों जैसा काम क्यों करते हो?"
 ], label=1.0 ), 
InputExample(texts=[ "Don't argue with stupid people"
, "मूर्ख लोगों से बहस नहीं करनी चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "Why do you always wear obsolete clothes?"
, "तुम हमेशा अप्रचलित पहनावा ही क्यों पहनते हो?"
 ], label=1.0 ), 
InputExample(texts=[ "Arjuna was proficient in archery"
, "अर्जुन धनुर्विद्या में प्रवीण थे"
 ], label=1.0 ), 
InputExample(texts=[ "This job requires a qualified person"
, "इस काम के लिए एक योग्य व्यक्ति की आवश्यकता है"
 ], label=1.0 ), 
InputExample(texts=[ "Ram is a decent man"
, "राम एक सभ्य व्यक्ति है"
 ], label=1.0 ), 
InputExample(texts=[ "There is no dearth of good people in the world"
, "दुनिया में अच्छे लोगों की कमी नहीं है"
 ], label=1.0 ), 
InputExample(texts=[ "Hunter targets cannibal tigress"
, "शिकारी ने नरभक्षी बाघिन को अपना निशाना बनाया"
 ], label=1.0 ), 
InputExample(texts=[ "Kalidas was one of the Navaratnas of Vikramaditya"
, "कालिदास विक्रमादित्य के नवरत्नों में से एक थे"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam spent all his life raising orphans"
, "श्याम ने अपना सारा जीवन अनाथ बच्चों की परवरिश में बिता दिया"
 ], label=1.0 ), 
InputExample(texts=[ "Surendraji keeps on helping the helpless people"
, "सुरेन्द्रजी असहाय व्यक्तियों की सहायता करते रहते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Fatherless children are sometimes directionless"
, "पितृहीन बच्चे कभी-कभी दिशाहीन हो जाते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Government is trying to mobilize resources for the poor people"
, "सरकार साधनहीन व्यक्तियों के लिए साधन जुटाने का प्रयास कर रही है"
 ], label=1.0 ), 
InputExample(texts=[ "Orphan children should help orphan children"
, "सनाथ बालकों को अनाथ बालकों की मदद करनी चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "A jackal was feeding milk to its baby in the forest"
, "जंगल में एक गीदड़ी अपने बच्चे को दूध पिला रही थी"
 ], label=1.0 ), 
InputExample(texts=[ "Helpful people should help others"
, "ससहाय व्यक्तियों को दूसरों की सहायता करनी चहिए"
 ], label=1.0 ), 
InputExample(texts=[ "Sethji became motherless in his childhood"
, "सेठजी बचपन में ही मातृहीन हो गए"
 ], label=1.0 ), 
InputExample(texts=[ "Resourceful people help in the development of society"
, "साधन संपन्न व्यक्ति समाज के विकास में सहायक होते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "We should not insult anyone"
, "हमें किसी का अपमान नहीं करना चाहिए / ससुराल में उसकी बड़ी भद्द हुई"
 ], label=1.0 ), 
InputExample(texts=[ "Rude turns a man into an animal"
, "अशिष्टता मानव को पशु बना देती है"
 ], label=1.0 ), 
InputExample(texts=[ "Parents should be respected"
, "माता पिता का सम्मान करना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "God is omnipresent / God is our protector"
, "ईश्वर सर्वव्यापी है/ ईश्वर हम सबके रक्षक हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Ramu adopted an unnamed boy from the orphanage"
, "रामू ने अनाथ आश्रम से एक अनाम बालक को गोद लिया"
 ], label=1.0 ), 
InputExample(texts=[ "According to religious texts, every act of nature is governed by divine power"
, "धर्म ग्रंथों के अनुसार प्रकृति का हर कार्य दिव्य शक्ति द्वारा संचालित होता है"
 ], label=1.0 ), 
InputExample(texts=[ "In ancient times, a king named Raghu ruled in Ayodhya"
, "प्राचीन काल में अयोध्या में रघु नामक राजा राज्य करते थे"
 ], label=1.0 ), 
InputExample(texts=[ "As soon as we got out of the house it suddenly started raining"
, "हम ज्यों ही घर से बाहर निकले अचानक बारिश होने लगी "
 ], label=1.0 ), 
InputExample(texts=[ "Nothing happens suddenly"
, "अनायास कोई काम नहीं होता"
 ], label=1.0 ), 
InputExample(texts=[ "do anything with effort"
, "कोई भी काम प्रयत्नपूर्वक करो"
 ], label=1.0 ), 
InputExample(texts=[ "Home Minister unveils statue of Gandhiji"
, "गृहमंत्री ने गाँधी जी की प्रतिमा का अनावरण किया"
 ], label=1.0 ), 
InputExample(texts=[ "Malin is plucking flowers by bending the branches of Kachnar"
, "मालिन कचनार की डालियाँ झुकाकर फूल तोड़ रही है"
 ], label=1.0 ), 
InputExample(texts=[ "The gardener was making a garland of kachnar"
, "माली कचनार की माला बना रहा था "
 ], label=1.0 ), 
InputExample(texts=[ "This University will be inaugurated by His Excellency Rashtrapatiji"
, "इस विश्वविद्यालय का उद्घाटन महामहिम राष्ट्रपतिजी करेंगे"
 ], label=1.0 ), 
InputExample(texts=[ "Farmer is putting compost in the empty field"
, "किसान खाली खेत में कंपोस्त डाल रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "The revelation of the sudden disappearance of Netaji Subhas Chandra Bose has not happened till today"
, "नेताजी सुभाष चंद्र बोस के अचानक लापता होने का रहस्योद्घाटन आज तक नहीं हुआ"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam is organizing the cluttered room"
, "श्याम अव्यवस्थित कमरे को व्यवस्थित कर रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "Hitler was an autocratic ruler"
, "हिटलर एक निरंकुश शासक था"
 ], label=1.0 ), 
InputExample(texts=[ "Today's young generation is blindly imitating western civilization"
, "आज की युवा पीढ़ी पाश्चात्य सभ्यता का अंधानुकरण कर रही है"
 ], label=1.0 ), 
InputExample(texts=[ "Work is easy if there is adaptability"
, "अनुकूलता हो तो काम करना सहज होता है"
 ], label=1.0 ), 
InputExample(texts=[ "Kindness is the ornament of a gentleman"
, "दयालुता सज्जन पुरुषों का आभूषण है"
 ], label=1.0 ), 
InputExample(texts=[ "Because of the compatibility of circumstances, he went on becoming successful in life"
, "परिस्थितियों की संगतता के कारण वह जीवन में सफल होता चला गया"
 ], label=1.0 ), 
InputExample(texts=[ "Throughout mutual harmony even the most difficult tasks are possible"
, "आपसी सामंजस्य के द्वारा कठिन से कठिन कार्य भी संभव है"
 ], label=1.0 ), 
InputExample(texts=[ "Let's start this new task"
, "आइए इस नए कार्य का आरंभ करते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Today's movies are full of nudity"
, "आज की फिल्में नग्नता से भरी होती हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Mother is teaching the child to read Kakhara"
, "मांॅ बच्चे को ककहरा पढ़ना सिखा रही है"
 ], label=1.0 ), 
InputExample(texts=[ "Goats eating the leaves of the crop in the fields"
, "बकरियाँ खेतों में फसल की पत्तियाँ खा रही हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Only after the reasons for the problem are clear, we can solve it"
, "समस्या के कारणों की स्पष्टता के बाद ही हम इसका समाधान कर सकते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Keep the secrecy of this secret"
, "इस रहस्य की गोपनीयता को बनाए रखो"
 ], label=1.0 ), 
InputExample(texts=[ "There is a sense of being beautiful in beauty"
, "सुंदरता में सुंदर होने का भाव है"
 ], label=1.0 ), 
InputExample(texts=[ "adversity complicates any task"
, "प्रतिकूलता किसी भी कार्य को जटिल बना देती है"
 ], label=1.0 ), 
InputExample(texts=[ "Virtuosity is the ornament of man"
, "सद्गुण मनुष्य का आभूषण है"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam donated blood at the hospital"
, "श्याम ने अस्पताल जाकर रक्त दान किया"
 ], label=1.0 ), 
InputExample(texts=[ "Work can be accelerated by removing discrepancies during work"
, "कार्य के दौरान आनेवाली विसंगतियों को दूर करके कार्य में तेज़ी लाई जा सकती है"
 ], label=1.0 ), 
InputExample(texts=[ "The hero and heroine meet at the end of the play"
, "नाटक की समाप्ति पर नायक और नायिका का मिलन हुआ"
 ], label=1.0 ), 
InputExample(texts=[ "Dissonance is a hindrance to progress"
, "असामंजस्यता उन्नति में बाधक होती है"
 ], label=1.0 ), 
InputExample(texts=[ "Bhaskar is my younger brother"
, "भाष्कर मेरा छोटा भाई है"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam is my cousin"
, "श्याम मेरा चचेरा भाई है"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam's elder brother is a teacher"
, "श्याम का बड़ा भाई अध्यापक है"
 ], label=1.0 ), 
InputExample(texts=[ "Rohan failed in the exam"
, "रोहन परीक्षा में अनुत्तीर्ण हो गया"
 ], label=1.0 ), 
InputExample(texts=[ "Passed candidates will be rewarded"
, "उत्तीर्ण परीक्षार्थियों को पुरस्कृत किया जायेगा"
 ], label=1.0 ), 
InputExample(texts=[ "Today Shyam was absent in class"
, "आज श्याम कक्षा में अनुपस्थित था"
 ], label=1.0 ), 
InputExample(texts=[ "There were ten students in the class today / Everything in the room was in place"
, "आज कक्षा में दस छात्र उपस्थित थे / कमरे की सभी चीजें अपनी जगह बरक़रार थीं"
 ], label=1.0 ), 
InputExample(texts=[ "It's Full of Caraba Fruit Juice"
, "यह कराबा फलों के रस से भरा हुआ है"
 ], label=1.0 ), 
InputExample(texts=[ "Use the present time, because the time gone never comes back"
, "वर्तमान समय का उपयोग करो,क्योंकि गया समय वापस नहीं आता"
 ], label=1.0 ), 
InputExample(texts=[ "The author is getting royalty on the ratio of two percent for the book"
, "पुस्तक के लिए लेखक को दो प्रतिशत के अनुपात से रायल्टी मिल रही है"
 ], label=1.0 ), 
InputExample(texts=[ "His Kajri eyes were mesmerizing"
, "उसकी कजरारी आँखें सबको सम्मोहित कर रही थीं"
 ], label=1.0 ), 
InputExample(texts=[ "It is an agreement between the two parties that they will not interfere in each other's affairs"
, "दोनों पक्षों के बीच यह अनुबंध हुआ कि वे एक दूसरे के मामले में दखल नहीं देंगे"
 ], label=1.0 ), 
InputExample(texts=[ "India Pak agreement is necessary on Kashmir issue"
, "कश्मीर मसले पर भारत पाक समझौता आवश्यक है"
 ], label=1.0 ), 
InputExample(texts=[ "He got the contract to build the road"
, "उसे सड़क बनवाने का ठेका मिला"
 ], label=1.0 ), 
InputExample(texts=[ "Nothing should be bought without a deal"
, "सौदा किये बगैर कोई भी सामान नहीं खरीदना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "Who will take the responsibility of doing this work?"
, "इस काम को करने की जिम्मेदारी कौन लेगा ?"
 ], label=1.0 ), 
InputExample(texts=[ "His business is flourishing day and night due to Ram's hard work"
, "राम की कड़ी मेहनत से उसका व्यापार दिन-रात फल फूल रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "He has experience in this work"
, "उसे इस काम का अनुभव है"
 ], label=1.0 ), 
InputExample(texts=[ "The mind becomes happy when the memory of childhood comes"
, "बचपन की स्मृति आते ही मन प्रसन्न हो जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "He has good knowledge of Sanskrit"
, "उसे संस्कृत का अच्छा ज्ञान है"
 ], label=1.0 ), 
InputExample(texts=[ "This job requires an experienced person"
, "इस काम के लिए एक अनुभवी व्यक्ति की आवश्यकता है"
 ], label=1.0 ), 
InputExample(texts=[ "Nowadays how difficult it is to get reservation in railways, only a beneficiary can know it"
, "आजकल रेल में आरक्षण मिलना कितना मुश्किल है यह कोई भुक्तभोगी ही जान सकता है"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam is still a beneficiary, once he stumbles, he will take care of himself"
, "श्याम अभी अभुक्तभोगी है, जब एक बार ठोकर लगेगी तो खुद ही सँभल जायेगा"
 ], label=1.0 ), 
InputExample(texts=[ "Sometimes there is a sense of future happenings / The unconscious body feeling is zero"
, "कभी-कभी भविष्य में घटित होनेवाली घटनाओं की अनुभूति हो जाती है / बेसुध शरीर अनुभूति शुन्य होता है"
 ], label=1.0 ), 
InputExample(texts=[ "It is difficult to control the mood / There are different types of emotions in the mind"
, "मनोभाव पर नियंत्रण करना कठिन होता है/ मन में तरह-तरह के भाव आते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "No work should be done without the permission of the elders"
, "बड़ों की अनुमति के बिना कोई भी काम नहीं करना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "Government of India has given its approval for commissioning of this project"
, "भारत सरकार ने इस परियोजना को चालू करने के लिए अपनी स्वीकृति दे दी है"
 ], label=1.0 ), 
InputExample(texts=[ "Sometimes the guesses are wrong"
, "कभी-कभी अनुमान गलत भी हो जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "The sculptor's imagination carves the stone and gives it a concrete form"
, "मूर्तिकार की कल्पना पत्थर को तराश कर मूर्त रूप प्रदान करती है"
 ], label=1.0 ), 
InputExample(texts=[ "We approve this offer"
, "हम इस प्रस्ताव का अनुमोदन करते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "His approval of my statement is a pretense"
, "मेरे वक्तव्य पर उसका अनुमोदन, ढोंग भरा है"
 ], label=1.0 ), 
InputExample(texts=[ "I fought the election despite Ram's resistance"
, "राम के प्रतिरोध के बावज़ूद भी मैने चुनाव लड़ा"
 ], label=1.0 ), 
InputExample(texts=[ "Frog is an amphibian"
, "मेंढक एक उभयचर प्राणी है"
 ], label=1.0 ), 
InputExample(texts=[ "Worldly things bring only momentary happiness by enamoring the mind"
, "सांसारिक वस्तुएँ मन को आसक्त करके क्षणिक सुख ही पहुँचाती हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Tulsidas was loyal to Lord Rama"
, "तुलसीदास भगवान राम के प्रति निष्ठावान थे"
 ], label=1.0 ), 
InputExample(texts=[ "My mom is a working woman"
, "मेरी माँ एक कामकाजी महिला हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Seth Deendayalji fulfills the needs of others through secret donation"
, "सेठ दीनदयालजी गुप्तदान के द्वारा ही दूसरों की आवश्यकताओं की पूर्ति करते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "There should be devotion to God"
, "ईश्वर के प्रति भक्ति होनी चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "Many languages ​​are spoken in India"
, "भारत में अनेक भाषाएँ बोली जाती हैं"
 ], label=1.0 ), 
InputExample(texts=[ "The brightness of the aura of ordinary human beings is not visible because of its diminution"
, "साधारण मनुष्यों के प्रभामंडल की दीप्ति क्षीण होने के कारण दिखाई नहीं पड़ती है"
 ], label=1.0 ), 
InputExample(texts=[ "There is no place for selfishness in love"
, "प्रेम में स्वार्थ का कोई स्थान नहीं होता"
 ], label=1.0 ), 
InputExample(texts=[ "Uncle Nehru was very fond of children"
, "चाचा नेहरू को बच्चों से बहुत ही स्नेह था"
 ], label=1.0 ), 
InputExample(texts=[ "He bought three replica idols"
, "उसने तीन प्रतिरूपी मूर्तियाँ खरीदी"
 ], label=1.0 ), 
InputExample(texts=[ "He doesn't want to act like me"
, "वह मेरे अनुसार काम करना नहीं चाहता"
 ], label=1.0 ), 
InputExample(texts=[ "Meera is wearing a Falsai sari"
, "मीरा फालसई साड़ी पहनी है"
 ], label=1.0 ), 
InputExample(texts=[ "It's not a good thing to turn down someone's request"
, "किसी के अनुरोध को ठुकराना अच्छी बात नहीं"
 ], label=1.0 ), 
InputExample(texts=[ "Shouldn't use antipsychotic drugs"
, "गतावधिक दवाओं का उपयोग नही करना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "The peon requested the officer for leave"
, "चपरासी ने छुट्टी के लिए अधिकारी से प्रार्थना की"
 ], label=1.0 ), 
InputExample(texts=[ "His petition was dismissed by the court"
, "उसकी याचिका न्यायालय द्वारा खारिज़ कर दी गयी"
 ], label=1.0 ), 
InputExample(texts=[ "Ramayana has been translated into most languages"
, "रामायण का अनुवाद अधिकांश भाषाओं में हुआ है"
 ], label=1.0 ), 
InputExample(texts=[ "This is a translated work of the President's English book"
, "यह राष्ट्रपति के अंग्रेज़ी पुस्तक की अनुदित कृति है"
 ], label=1.0 ), 
InputExample(texts=[ "The interpretation of Sanskrit shlokas is not for everyone"
, "संस्कृत श्लोकों की व्याख्या सबके बस की बात नहीं है"
 ], label=1.0 ), 
InputExample(texts=[ "Ram trades in exchange"
, "राम विनिमय व्यापार करता है"
 ], label=1.0 ), 
InputExample(texts=[ "Whatever work my grandfather starts, he gets his breath by completing it"
, "मेरे दादाजी जो भी कार्य आरंभ करते हैं,उसे पूरा करके ही दम लेते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Mahatma people are absorbed in Dharma-karma"
, "महात्मा लोग धर्म-कर्म में लीन हैं"
 ], label=1.0 ), 
InputExample(texts=[ "He organized Mangalotsav on his son's birthday"
, "बेटे के जन्मदिवस पर उसने मंगलोत्सव का आयोजन किया"
 ], label=1.0 ), 
InputExample(texts=[ "Yajan begins in Hanuman temple"
, "हनुमान मंदिर में यजन शुरु है"
 ], label=1.0 ), 
InputExample(texts=[ "After the concept, he got engaged in his work with double zeal"
, "संकल्पना के बाद वह दूने उत्साह से अपने कार्य में लग गया"
 ], label=1.0 ), 
InputExample(texts=[ "Robots are the product of scientific research"
, "रोबोट वैज्ञानिक अनुसंधान की देन है"
 ], label=1.0 ), 
InputExample(texts=[ "Columbus Discovered America"
, "कोलम्बस ने अमेरिका की खोज की"
 ], label=1.0 ), 
InputExample(texts=[ "It's an imitation creation"
, "यह एक अनुकृत रचना है"
 ], label=1.0 ), 
InputExample(texts=[ "After much thought we found a solution to the problem"
, "बहुत चिंतन के बाद हमनें समस्या का हल ढूँढ़ निकाला"
 ], label=1.0 ), 
InputExample(texts=[ "Hate no one, for we are all children of the same God / He looked at me with envy"
, "किसी से भी घृणा मत करो,क्योंकि हम सभी एक ही ईश्वर की सन्तानें हैं / उसने मुझे हक़ारत भरी नज़र से देखा"
 ], label=1.0 ), 
InputExample(texts=[ "He has become detached from the country and the world"
, "उसे देश दुनिया से विरक्ति हो गयी है"
 ], label=1.0 ), 
InputExample(texts=[ "There are different images of Shiva in this temple"
, "इस मंदिर में शिव की भिन्नरूपी प्रतिमाएँ हैं"
 ], label=1.0 ), 
InputExample(texts=[ "This is a translated work of Mahasweta Devi"
, "यह महाश्वेता देवी की अनुदित कृति है"
 ], label=1.0 ), 
InputExample(texts=[ "Godan is Premchand's original work"
, "गोदान प्रेमचंद की मौलिक कृति है"
 ], label=1.0 ), 
InputExample(texts=[ "He was not blown away by the message of his brother's marriage"
, "अपने भाई की शादी का संदेश पाकर वह फूला नहीं समाया"
 ], label=1.0 ), 
InputExample(texts=[ "Ram Charit Manas of Tulsidas is a world famous literary work"
, "तुलसीदास का राम चरित मानस विश्व प्रसिद्ध साहित्यिक कृति है"
 ], label=1.0 ), 
InputExample(texts=[ "Opposition seeks clarification from government on their economic policy proposal"
, "विपक्ष ने सरकार से उनकी आर्थिक नीति प्रस्ताव पर स्पष्टीकरण माँगा"
 ], label=1.0 ), 
InputExample(texts=[ "This chapter focuses on verbs"
, "इस अध्याय में क्रिया के ऊपर प्रकाश डाला गया है"
 ], label=1.0 ), 
InputExample(texts=[ "If the beginning is good then the end is also good"
, "आरंभ ठीक हो तो अंत भी ठीक ही होता है"
 ], label=1.0 ), 
InputExample(texts=[ "Society without unity cannot develop"
, "एकताहीन समाज विकास नहीं कर पाता है"
 ], label=1.0 ), 
InputExample(texts=[ "He put inedible things in the garbage can"
, "उसने अखाद्य वस्तुओं को कचरे के डिब्बे में डाल दिया"
 ], label=1.0 ), 
InputExample(texts=[ "There is a fig orchard in front of my house"
, "मेरे घर के सामने अंजीर का एक बाग है"
 ], label=1.0 ), 
InputExample(texts=[ "There are other people with me"
, "मेरे साथ और लोग भी हैं"
 ], label=1.0 ), 
InputExample(texts=[ "The family should also be respected"
, "परजन का भी आदर करना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "The people of Arya Samaj do not believe in idol worship or mythological rituals etc."
, "आर्य समाज के लोग मूर्तिपूजा या पौराणिक रीतियाँ आदि नहीं मानते"
 ], label=1.0 ), 
InputExample(texts=[ "The question paper has two compulsory and four optional questions"
, "प्रश्न पत्र में दो अनिवार्य और चार वैकल्पिक प्रश्न हैं"
 ], label=1.0 ), 
InputExample(texts=[ "The invention of computer brought a great change in the society"
, "संगणक के आविष्कार ने समाज में एक बहुत बड़ा परिवर्तन ला दिया"
 ], label=1.0 ), 
InputExample(texts=[ "We must help persons with disabilities"
, "हमें विकलांग व्यक्तियों की मदद करनी चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "Daanveer Karna was not Auras' son"
, "दानवीर कर्ण औरस पुत्र नहीं था"
 ], label=1.0 ), 
InputExample(texts=[ "This is my personal property"
, "यह मेरी निजी संपत्ति है"
 ], label=1.0 ), 
InputExample(texts=[ "This is my house"
, "यह मेरा घर है"
 ], label=1.0 ), 
InputExample(texts=[ "This is my original creation"
, "यह मेरी मौलिक रचना है"
 ], label=1.0 ), 
InputExample(texts=[ "A relative of mine lives in Delhi"
, "मेरे एक रिश्तेदार दिल्ली में रहते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "It's my personal matter"
, "यह मेरा वैयक्तिक मामला है"
 ], label=1.0 ), 
InputExample(texts=[ "It's a personal matter"
, "यह स्वजनीय मामला है"
 ], label=1.0 ), 
InputExample(texts=[ "Indigenous goods should be used"
, "स्वदेशीय वस्तुओं का प्रयोग करना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "This is an independent matter"
, "यह स्वपक्षीय मामला है"
 ], label=1.0 ), 
InputExample(texts=[ "The fame of Ratnakar as a dacoit is greater than that of sage Valmiki"
, "डाकू के रूप में रत्नाकर को जितनी बदनामी मिली,उससे अधिक ऋषि वाल्मीकि के रूप में प्रसिद्धि"
 ], label=1.0 ), 
InputExample(texts=[ "It is a crime to employ child labor"
, "बाल श्रमिक से काम कराना एक अपराध है"
 ], label=1.0 ), 
InputExample(texts=[ "The culprit must be punished"
, "अपराधी व्यक्ति को सज़ा मिलनी ही चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "He's Playing the Harmonia"
, "वह हरमोनिया बजा रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "He will come this afternoon"
, "वह आज अपराह्न में आयेगा"
 ], label=1.0 ), 
InputExample(texts=[ "There are exceptions to this rule"
, "इस नियम के कुछ अपवाद भी हैं"
 ], label=1.0 ), 
InputExample(texts=[ "I have committed a non-cognizable offence"
, "मुझसे एक असंज्ञेय अपराध हो गया"
 ], label=1.0 ), 
InputExample(texts=[ "Two criminals killed in police encounter"
, "दो अपराधी पुलिस मुठभेड़ में मारे गए"
 ], label=1.0 ), 
InputExample(texts=[ "It is not okay to slander someone's character without thinking"
, "बिना सोचे समझे किसी के चरित्र पर लांछन लगाना ठीक नहीं है"
 ], label=1.0 ), 
InputExample(texts=[ "Untreated water is injurious to health"
, "अशोधित जल स्वास्थ्य के लिए हानिकारक होता है"
 ], label=1.0 ), 
InputExample(texts=[ "Don't eat leftover food"
, "उच्छिष्ठ भोजन नहीं करना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "As soon as Ram climbed Lanka, bad omen started happening in Lanka"
, "राम ने ज्योहिं लंका पर चढ़ाई की,लंका में अपशकुन होने लगे"
 ], label=1.0 ), 
InputExample(texts=[ "Subjects should not be used"
, "कुवचन का प्रयोग नहीं करना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "He always does a good job"
, "वह हमेशा अच्छा काम ही करता है"
 ], label=1.0 ), 
InputExample(texts=[ "Avoid iniquity"
, "अधर्म कर्म से बचो"
 ], label=1.0 ), 
InputExample(texts=[ "Independence Day is our National Festival"
, "स्वतंत्रता दिवस हमारा राष्ट्रीय त्योहार है"
 ], label=1.0 ), 
InputExample(texts=[ "he is good at playing the piano"
, "वह पियानो बजाने में निपुण है"
 ], label=1.0 ), 
InputExample(texts=[ "It's not a man's job"
, "यह काम एक आदमी के बस का नहीं है"
 ], label=1.0 ), 
InputExample(texts=[ "A unitary society moves on the path of development"
, "एकतापूर्ण समाज विकास के पथ पर अग्रसर रहता है"
 ], label=1.0 ), 
InputExample(texts=[ "Should work in the interest of the people"
, "जन के हित में काम करना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "Ramu is a brash boy"
, "रामू एक ढीठ लड़का है"
 ], label=1.0 ), 
InputExample(texts=[ "Working with the spirit of welfare of the people is not in the interest of the society"
, "स्वजन कल्याण की भावना से काम करना,समाज के हित में नहीं होता"
 ], label=1.0 ), 
InputExample(texts=[ "Still in most families endogamous marriage is accepted"
, "अभी भी अधिकतर परिवारों में सजातीय विवाह को ही स्वीकार किया जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "In the face of this problem, I have become choiceless"
, "इस समस्या के सामने मैं विकल्पहीन हो गया"
 ], label=1.0 ), 
InputExample(texts=[ "He's a handicapped person, pretending to be a handicap"
, "वह अनपंग व्यक्ति है,अपंग होने का नाटक कर रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "Your house is too cute"
, "तुम्हारा घर भी बहुत प्यारा है"
 ], label=1.0 ), 
InputExample(texts=[ "Everybody's preference is different"
, "हर व्यक्ति की पसंद अलग-अलग होती है"
 ], label=1.0 ), 
InputExample(texts=[ "Shouldn't get into foreign affairs / It's alien property"
, "पराये मामलों में नहीं पड़ना चाहिए / यह पराई संपति है"
 ], label=1.0 ), 
InputExample(texts=[ "Many foreign tourists visit India everyday"
, "भारत में कई विदेशी पर्यटक प्रतिदिन आते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Opposition party meeting is being held tonight"
, "आज शाम विपक्षीय दल की बैठक हो रही है"
 ], label=1.0 ), 
InputExample(texts=[ "There are no vacant rooms in the guest house"
, "अतिथि गृह में कोई कमरा खाली नहीं है"
 ], label=1.0 ), 
InputExample(texts=[ "The lotus is in bloom in the reservoir"
, "जलाशय में कमल खिले हुए हैं"
 ], label=1.0 ),
InputExample(texts=[ "The demons used to worship Lord Shiva and get arbitrary grooms"
, "राक्षस औढरदानी भगवान शिव की उपासना कर मनमाना वर पा जाते थे"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam is drinking tea sitting on the verandah"
, "श्याम बरामदे में बैठकर चाय पी रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "This is the main gate of this fort"
, "यह इस किले का मुख्य द्वार है"
 ], label=1.0 ), 
InputExample(texts=[ "Right now my planetary condition is going very well"
, "अभी मेरी ग्रह दशा बहुत अच्छी चल रही है"
 ], label=1.0 ), 
InputExample(texts=[ "The position of the planets is determined according to the zodiac"
, "राशि चक्र के अनुसार ग्रहों की स्थिति का निर्धारण होता है"
 ], label=1.0 ), 
InputExample(texts=[ "My zodiac sign is Virgo"
, "मेरी राशि कन्या है"
 ], label=1.0 ), 
InputExample(texts=[ "Earth is a planet"
, "पृथ्वी एक ग्रह है"
 ], label=1.0 ), 
InputExample(texts=[ "Gautam Buddha was a revered man"
, "गौतम बुद्ध एक पूजनीय व्यक्ति थे"
 ], label=1.0 ), 
InputExample(texts=[ "There is a law in Islam to offer prayers five times a day"
, "इस्लाम धर्म में दिनभर में पाँच बार नमाज़ पढ़ने का विधान है"
 ], label=1.0 ), 
InputExample(texts=[ "The first worshiped god is Ganeshji / The idol is worshiped with milk, curd, sugar etc."
, "प्रथम पूजित देव गणेशजी हैं / पूजित मूर्ति पर दूध, दही,शक्कर आदि चढ़ा है"
 ], label=1.0 ), 
InputExample(texts=[ "It is the duty of every person to serve the parents"
, "माता-पिता की सेवा करना हर व्यक्ति का कर्तव्य होता है"
 ], label=1.0 ), 
InputExample(texts=[ "I am a supporter of justice"
, "मैं न्याय का समर्थक हूँ"
 ], label=1.0 ), 
InputExample(texts=[ "My elder sister is a teacher"
, "मेरी बड़ी बहन अध्यापिका हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Many gold mines unearthed in Karnataka"
, "कर्नाटक में कई स्वर्ण खानों का पता चला है"
 ], label=1.0 ), 
InputExample(texts=[ "The search for iron deposits in this area continues"
, "इस क्षेत्र में लौह भंडार की खोज जारी है"
 ], label=1.0 ), 
InputExample(texts=[ "Iron is very useful for humans"
, "लोहा मानव के लिए बहुत ही उपयोगी है"
 ], label=1.0 ), 
InputExample(texts=[ "Opposition created ruckus in Parliament"
, "विपक्षियों ने संसद में हंगामा कर दिया"
 ], label=1.0 ), 
InputExample(texts=[ "Lord Rama was incarnated in the Surya dynasty"
, "सूर्य वंश में भगवान राम अवतरित हुए थे"
 ], label=1.0 ), 
InputExample(texts=[ "The Pandavas and Kauravas belonged to the Chandra dynasty"
, "पाँडव तथा कौरव चंद्रवंश के थे"
 ], label=1.0 ), 
InputExample(texts=[ "Respect Gentlemen"
, "सज्जनों का आदर करो"
 ], label=1.0 ), 
InputExample(texts=[ "Avoid the company of the wicked"
, "दुर्जन की संगति से बचें"
 ], label=1.0 ), 
InputExample(texts=[ "Our principal's name is Shri Pushpak Bhattacharya"
, "हमारे प्राचार्य जी का नाम श्री पुष्पक भट्टाचार्य है"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam was honored with a doctorate"
, "श्याम को डॉक्टर की उपाधि से सम्मानित किया गया"
 ], label=1.0 ), 
InputExample(texts=[ "Life on Mercury is Impossible"
, "बुध पर जीवन असम्भव है"
 ], label=1.0 ), 
InputExample(texts=[ "Scientists are engaged in gathering information about Venus"
, "वैज्ञानिक शुक्र के बारे में जानकारी इकट्ठा करने में लगे हुए हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Jupiter is the biggest of all the planets"
, "बृहस्पति सब ग्रहों में बड़ा है"
 ], label=1.0 ), 
InputExample(texts=[ "Saturn is far away from Earth"
, "शनि पृथ्वी से अत्यधिक दूर है"
 ], label=1.0 ), 
InputExample(texts=[ "Varuna was discovered in the year nineteen hundred eighty-four"
, "सन् उन्नीस सौ चौरासी में वरुण का पता चला था"
 ], label=1.0 ), 
InputExample(texts=[ "Scientists have excluded Yama from the solar system without considering it as a planet"
, "वैज्ञानिकों ने यम को ग्रह न मानते हुए इसको सौरमंडल से बाहर कर दिया है"
 ], label=1.0 ), 
InputExample(texts=[ "There are now twenty nine states in independent India"
, "स्वतंत्र भारत में अब उनतीस प्रदेश हो गए हैं"
 ], label=1.0 ), 
InputExample(texts=[ "He is a resident of Gorakhpur division of Uttar Pradesh"
, "वह उत्तर प्रदेश के गोरखपुर मंडल का रहनेवाला है"
 ], label=1.0 ), 
InputExample(texts=[ "A circle consists of many districts"
, "एक मंडल में कई जिले होते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Seeing the wolf, the shepherd shouted, save-save, the wolf has come"
, "भेड़िये को देखकर गड़ेरिया चिल्लाया,बचाओ-बचाओ,भेड़िया आ गया"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam was crying because of separation from his mother"
, "अपनी माँ से बिछुड़ने के कारण श्याम रो रहा था"
 ], label=1.0 ), 
InputExample(texts=[ "She's singing in a sweet voice"
, "वह मीठे स्वर में गा रही है"
 ], label=1.0 ), 
InputExample(texts=[ "He was moaning lying on the cot"
, "वह खाट पर पड़े-पड़े कराह रहा था"
 ], label=1.0 ), 
InputExample(texts=[ "She's still sobbing"
, "वह अभी भी सिसक रही है"
 ], label=1.0 ), 
InputExample(texts=[ "Tears flow from my eyes while chopping onions"
, "प्याज काटते समय आँखों से आँसू बहता है"
 ], label=1.0 ), 
InputExample(texts=[ "Mandodari started mourning after hearing the news of Meghnad's death."
, "मेघनाद की मृत्यु का समाचार सुनकर मंदोदरी विलाप करने लगी"
 ], label=1.0 ), 
InputExample(texts=[ "Tehsildar is the highest officer of Tehsil"
, "तहसील का सबसे बड़ा अधिकारी तहसीलदार होता है"
 ], label=1.0 ), 
InputExample(texts=[ "Ram and Shyam are arguing over unnecessary issues"
, "राम और श्याम अनावश्यक मसले पर वाद विवाद कर रहे हैं"
 ], label=1.0 ), 
InputExample(texts=[ "He's sitting in the house doing witchcraft"
, "वह घर में बैठकर वितंडा कर रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "A boy was threatening my younger brother"
, "एक लड़का मेरे छोटे भाई को धमका रहा था"
 ], label=1.0 ), 
InputExample(texts=[ "He expresses emotion through his poetry"
, "वह अपनी कविता के माध्यम से भावाभिव्यक्ति करता है"
 ], label=1.0 ), 
InputExample(texts=[ "He Expresses His Thoughts"
, "उसने अपने विचारों को अभिव्यक्त किया"
 ], label=1.0 ), 
InputExample(texts=[ "Yudhisthir was a truthful man"
, "युधिष्ठिर एक सत्यवादी व्यक्ति थे"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam is a reliable person"
, "श्याम विश्वसनीय व्यक्ति है"
 ], label=1.0 ), 
InputExample(texts=[ "He keeps telling imaginary things to everyone"
, "वह काल्पनिक बातें सबको सुनाता रहता है"
 ], label=1.0 ), 
InputExample(texts=[ "He's heating cast iron on fire"
, "वह कच्चे लोहे को आग पर तपा रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "Weapons are made from cast iron"
, "ढले लोहे से अस्त्र-शस्त्र का निर्माण किया जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "Mohan does not write Vansh name with his name"
, "मोहन अपने नाम के साथ वंश नाम नहीं लिखता है"
 ], label=1.0 ), 
InputExample(texts=[ "Poet Ramdhari Singh is famous by his surname Dinkar"
, "कवि रामधारी सिंह अपने उपनाम दिनकर से प्रसिद्ध हैं"
 ], label=1.0 ), 
InputExample(texts=[ "The integer of this question paper is hundred"
, "इस प्रश्न-पत्र का पूर्णांक सौ है"
 ], label=1.0 ), 
InputExample(texts=[ "My score in Hindi is seventy percent"
, "हिन्दी में मेरा प्राप्तांक सत्तर प्रतिशत है"
 ], label=1.0 ), 
InputExample(texts=[ "Today the teacher has given a different number of questions for homework"
, "आज अध्यापकजी ने गृह कार्य के लिए भिन्न संख्या से संबंधित प्रश्न दिए हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Two thirds of an object have three denominators"
, "किसी वस्तु के दो तिहाई में तीन हर है"
 ], label=1.0 ), 
InputExample(texts=[ "Write these numbers in Roman numerals"
, "इन संख्याओं को रोमन अंक में लिखिये"
 ], label=1.0 ), 
InputExample(texts=[ "Hindi is written in Devanagari script"
, "हिन्दी देवनागरी लिपि में लिखी जाती है"
 ], label=1.0 ), 
InputExample(texts=[ "Hindi has thirteen vowel letters"
, "हिन्दी में तेरह स्वर अक्षर हैं"
 ], label=1.0 ), 
InputExample(texts=[ "All letters from A to H are called consonants in the Hindi alphabet"
, "हिन्दी वर्णमाला में क से लेकर ह तक के सभी वर्ण व्यंजन कहलाते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "My name is written in composite letters"
, "मेरा नाम संयुक्त अक्षर में लिखा जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "There are three types of cartilage"
, "उपास्थि तीन प्रकार की होती हैं"
 ], label=1.0 ), 
InputExample(texts=[ "The ancient scripts of China are examples of hieroglyphs"
, "चीन की प्राचीन लिपियाँ चित्रलिपि की उदाहरण हैं"
 ], label=1.0 ), 
InputExample(texts=[ "He is leveling the uncultivated land to cultivate"
, "वह खेती करने के लिए असमतल भूमि को समतल कर रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "He's drinking grape wine"
, "वह अंगूरी शराब पी रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "His hip was damaged during the accident"
, "दुर्घटना के दौरान उसका कूल्हा क्षतिग्रस्त हो गया"
 ], label=1.0 ), 
InputExample(texts=[ "Sit up straight to keep the spine straight"
, "मेरुदंड को सीधा रखने के लिए सीधे बैठें"
 ], label=1.0 ), 
InputExample(texts=[ "Your power will be revealed in this work"
, "इस कार्य के दौरान आपकी शक्ति का पता चल जायेगा"
 ], label=1.0 ), 
InputExample(texts=[ "He was so scared that his voice couldn't come out of his mouth"
, "वह इतना डर गया था कि उसके मुँह से आवाज़ बाहर नहीं निकल रही थी"
 ], label=1.0 ), 
InputExample(texts=[ "He lost many of his teeth in the accident"
, "दुर्घटना में उसने अपने कई दाँत खो दिए"
 ], label=1.0 ), 
InputExample(texts=[ "Rama's palate is swollen"
, "राम के तालु में सूजन आ गई है"
 ], label=1.0 ), 
InputExample(texts=[ "Ram's gum is swollen"
, "राम के मसूड़े में सूजन है"
 ], label=1.0 ), 
InputExample(texts=[ "You have put a question mark where you should put punctuation"
, "जहाँ विराम चिह्न लगाना चाहिए,वहाँ आपने प्रश्न वाचक चिह्न लगा दिया है"
 ], label=1.0 ), 
InputExample(texts=[ "Punctuation has great importance in grammar"
, "व्याकरण में विराम चिह्न का बड़ा महत्व है"
 ], label=1.0 ), 
InputExample(texts=[ "Put a tick mark next to the sentence that is correct"
, "जो वाक्य सही हो उसके आगे सही का चिह्न लगाओ"
 ], label=1.0 ), 
InputExample(texts=[ "Put a wrong mark in front of the sentence which is not correct"
, "जो वाक्य सही न हो उसके आगे गलत चिह्न लगाओ"
 ], label=1.0 ), 
InputExample(texts=[ "Diamond studded jewelery is very expensive"
, "हीरे जड़ित आभूषण बहुत महँगे होते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "The realization of true happiness is possible only through the love of God"
, "सच्चे आनन्द की अनुभूति ईश्वर प्रेम से ही संभव है"
 ], label=1.0 ), 
InputExample(texts=[ "There should be no blind devotion towards anyone"
, "किसी के प्रति अंध भक्ति नहीं होनी चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "Kirtan has great importance under Navadha Bhakti in Kaliyuga"
, "कलियुग में नवधा भक्ति के अंतर्गत कीर्तन का बड़ा महत्व है"
 ], label=1.0 ), 
InputExample(texts=[ "This saree is painted red"
, "यह साड़ी लाल रंग से रंगी गई है"
 ], label=1.0 ), 
InputExample(texts=[ "She dyed the dhoti raw"
, "उसने धोती को कच्चे रंग में रंगा"
 ], label=1.0 ), 
InputExample(texts=[ "There is a law to worship Vat on Akshayatritiya"
, "अक्षयतृतीया को वट के पूजन का विधान है"
 ], label=1.0 ), 
InputExample(texts=[ "Saints have a strong feeling of God's love / He started screaming as soon as he felt the pain"
, "संतों को ईश्वर प्रेम की तीव्र अनुभूति होती है/ दर्द की तीव्र अनुभूति होते ही वह चिल्लाने लगा"
 ], label=1.0 ), 
InputExample(texts=[ "Hard water makes it difficult to wash clothes"
, "कठोर जल से कपड़े धोने में कठिनाई होती है"
 ], label=1.0 ), 
InputExample(texts=[ "Clothes are easily washed in soft water"
, "मृदु जल में कपड़े आसानी से धुलते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "walking is an intransitive verb"
, "चलना एक अकर्मक क्रिया है"
 ], label=1.0 ), 
InputExample(texts=[ "He is drinking water in that drink is a transitive verb"
, "वह पानी पी रहा है में पीना सकर्मक क्रिया है"
 ], label=1.0 ), 
InputExample(texts=[ "One third of the earth is land"
, "पृथ्वी का एक तिहाई भाग ही थल है"
 ], label=1.0 ), 
InputExample(texts=[ "The rhinoceros was hitting the trunk of the tree with the cane"
, "गैंडा खाँग से पेड़ के तने पर वार कर रहा था"
 ], label=1.0 ), 
InputExample(texts=[ "The wild boar tore the lamb out of its mouth"
, "जंगली सूअर ने खाँग से मेमने को फाड़ दिया"
 ], label=1.0 ), 
InputExample(texts=[ "drop by drop fills up"
, "बूँद-बूँद से घट भरता है"
 ], label=1.0 ), 
InputExample(texts=[ "Oil splattered on my clothes"
, "मेरे कपड़े पर तेल का छींटा पड़ गया है"
 ], label=1.0 ), 
InputExample(texts=[ "Human life is like a bubble of water"
, "मानव जीवन पानी के बुलबुले के समान है"
 ], label=1.0 ), 
InputExample(texts=[ "Child crime can be stopped by moral education"
, "नैतिक शिक्षा के द्वारा बाल अपराध को रोका जा सकता है"
 ], label=1.0 ), 
InputExample(texts=[ "A feather is coming out of his wound"
, "उसके घाव से पंछा निकल रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "The soldiers were bleeding, yet they stood in the field"
, "सैनिकों के शरीर से खून बह रहा था फिर भी वे मैदान में डटे हुए थे"
 ], label=1.0 ), 
InputExample(texts=[ "Brahmi script is the mother of Devanagari"
, "ब्राह्मी लिपि देवनागरी की जननी है"
 ], label=1.0 ), 
InputExample(texts=[ "Today Kharosthri script has become endangered"
, "आज खरोष्ठ्री लिपि लुप्तप्राय हो गयी है"
 ], label=1.0 ), 
InputExample(texts=[ "The origin of Devanagari script is believed to be from the Brahmi script."
, "देवनागरी लिपि की उत्पत्ति ब्राह्मी लिपि से मानी जाती है"
 ], label=1.0 ), 
InputExample(texts=[ "There is no religion like charity"
, "परोपकार के समान कोई धर्म नहीं है"
 ], label=1.0 ), 
InputExample(texts=[ "It is difficult to find a confidant in Kaliyuga"
, "कलियुग में विश्वासपात्र मिलना मुश्किल है"
 ], label=1.0 ), 
InputExample(texts=[ "Identifying the untrustworthy is difficult in the modern age"
, "आधुनिक युग में अविश्वासपात्र की पहचान मुश्किल है"
 ], label=1.0 ), 
InputExample(texts=[ "A is a vowel sound"
, "अ ह्रस्व स्वर है"
 ], label=1.0 ), 
InputExample(texts=[ "Om has a long vowel"
, "ओम में दीर्घ स्वर है"
 ], label=1.0 ), 
InputExample(texts=[ "The venom in the snake is the teeth"
, "सर्प में विष दंत पाये जाते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Falling broke two teeth of the little boy"
, "गिरने से छोटे बालक की दो दँतुरिया टूट गईं"
 ], label=1.0 ), 
InputExample(texts=[ "Discipline is what makes a nation great"
, "अनुशासन ही देश को महान् बनाता है"
 ], label=1.0 ), 
InputExample(texts=[ "Having a broken molar makes it difficult to eat"
, "एक दाढ़ के टूट जाने से खाने में परेशानी हो रही है"
 ], label=1.0 ), 
InputExample(texts=[ "His crooked tooth is clearly visible when he laughs"
, "हँसते समय उसका कुक्कुर दाँत स्पष्ट दिखाई देता है"
 ], label=1.0 ), 
InputExample(texts=[ "He solves the math problem in a pinch"
, "वह बीज गणित का प्रश्न चुटकी बजाते ही हल कर देता है"
 ], label=1.0 ), 
InputExample(texts=[ "What is the sum of the total marks?"
, "कुल अंकों का जोड़ कितना हुआ ?"
 ], label=1.0 ), 
InputExample(texts=[ "After subtracting the answer is four"
, "घटाने के बाद उत्तर चार आया"
 ], label=1.0 ), 
InputExample(texts=[ "By doing multiplication of two and two, the result of multiplication is four"
, "दो और दो का गुणन कर्म करने पर गुणन फल चार आता है"
 ], label=1.0 ), 
InputExample(texts=[ "Bhaag Karma will be taught in math class today"
, "आज गणित की कक्षा में भाग कर्म सिखाया जायेगा"
 ], label=1.0 ), 
InputExample(texts=[ "Many new colors are made by mixing the main colors together"
, "मुख्य रंगों को आपस में मिलाकर कई नए रंग बनाए जाते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Violet is an accessory color"
, "बैगनी एक गौण रंग है"
 ], label=1.0 ), 
InputExample(texts=[ "Plavica provides essential substances to the cells found inside it"
, "प्लाविका अपने अंदर पाई जानेताली कोशिकाओं को आवश्यक पदार्थ उपलब्ध कराती है"
 ], label=1.0 ), 
InputExample(texts=[ "There are many types of blood cells"
, "रक्त कोशिका कई प्रकार की होती हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Red blood cells carry oxygen"
, "लाल रक्त कणिकाएँ ऑक्सीजन का संवाहन करती हैं"
 ], label=1.0 ), 
InputExample(texts=[ "When cut somewhere in the body, the white blood cells collect and stop the flow of blood"
, "शरीर में कहीं कट जाने पर श्वेत रक्त कणिकाएँ जमा होकर रक्त का बहना बंद कर देती हैं"
 ], label=1.0 ), 
InputExample(texts=[ "The life of a benevolent person is peaceful"
, "उपकारी व्यक्ति का जीवन शांतिमय होता है"
 ], label=1.0 ), 
InputExample(texts=[ "I find pleasure in philanthropy"
, "मुझे लोकोपकार में सुखद अनुभूति की प्राप्ति होती है"
 ], label=1.0 ), 
InputExample(texts=[ "A bad person can never sleep peacefully"
, "अपकारी व्यक्ति कभी भी चैन की नींद नहीं सो सकता"
 ], label=1.0 ), 
InputExample(texts=[ "Hatim was a philanthropist"
, "हातिम एक परोपकारी व्यक्ति था"
 ], label=1.0 ), 
InputExample(texts=[ "Disciplinary action will be taken against the corrupt members of the organization"
, "संस्था के भ्रष्टाचारी सदस्यों के खिलाफ अनुशासनिक कार्यवाही की जायेगी"
 ], label=1.0 ), 
InputExample(texts=[ "Government is running philanthropic schemes"
, "सरकार लोकोपकारी योजनाएँ चला रही है"
 ], label=1.0 ), 
InputExample(texts=[ "Sneezing is an involuntary action"
, "छींक अनैच्छिक क्रिया है"
 ], label=1.0 ), 
InputExample(texts=[ "The heroine is portrayed as an unknown youth in this literary work"
, "इस साहित्यिक कृति में नायिका को अज्ञातयौवना के रूप में चित्रित किया गया है"
 ], label=1.0 ), 
InputExample(texts=[ "The heroine in this literary work is portrayed as a known youth"
, "इस साहित्यिक कृति में नायिका का चित्रण ज्ञातयौवना के रूप में किया गया है"
 ], label=1.0 ), 
InputExample(texts=[ "The parrot flew out of the cage"
, "तोंता पिंजरे से उड़ गया"
 ], label=1.0 ), 
InputExample(texts=[ "A fat mouse is trapped in the mousetrap"
, "चूहेदानी में एक मोटा चूहा फँस गया है"
 ], label=1.0 ), 
InputExample(texts=[ "The rat is munching on the clothes"
, "चुहिया कपड़े कुतर रही है"
 ], label=1.0 ), 
InputExample(texts=[ "He bought rat medicine from the market"
, "उसने बाजार से चूहा मारने की दवा खरीदा"
 ], label=1.0 ), 
InputExample(texts=[ "The rat is a rodent"
, "चूहा एक कृतंक जंतु है"
 ], label=1.0 ), 
InputExample(texts=[ "Man is a mammal"
, "मनुष्य एक स्तनपायी जन्तु है"
 ], label=1.0 ), 
InputExample(texts=[ "Human is a vertebrate animal"
, "मानव एक कशेरुकी जन्तु है"
 ], label=1.0 ), 
InputExample(texts=[ "He dyed the dhoti in a solid color"
, "उसने धोती को पक्के रंग में रंगा"
 ], label=1.0 ), 
InputExample(texts=[ "She Bought a Wood Cage to Raise Myself"
, "उसने मैना पालने के लिए एक काष्ठ पिंजर खरीदा"
 ], label=1.0 ), 
InputExample(texts=[ "Cheetah was locked in a metal cage"
, "चीता धातु पिंजर में बंद था"
 ], label=1.0 ), 
InputExample(texts=[ "She's making a basket with a splinter"
, "वह खपची से टोकरी बना रही है"
 ], label=1.0 ), 
InputExample(texts=[ "Lion is locked in an iron cage"
, "शेर लौह पिंजर में बंद है"
 ], label=1.0 ), 
InputExample(texts=[ "He twisted the bar with his hand"
, "उसने सरिया को हाथ से टेड़ा कर दिया"
 ], label=1.0 ), 
InputExample(texts=[ "Someone has given me this pen as a gift"
, "यह कलम किसी ने मुझे उपहार स्वरूप प्रदान की है"
 ], label=1.0 ), 
InputExample(texts=[ "He got me signed on plain paper"
, "उसने सादे कागज पर मेरा हस्ताक्षर करवाया"
 ], label=1.0 ), 
InputExample(texts=[ "In ancient times peacock feathers were used as writing instruments"
, "प्राचीन काल में मोर पंख लेखन उपकरण के रूप में प्रयोग किया जाता था"
 ], label=1.0 ), 
InputExample(texts=[ "Painted Curtain Hanging on the Door"
, "चित्रांकित परदा दरवाज़े पर लटक रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "I like to do voluntary work"
, "मैं ऐच्छिक कार्य करना पसंद करता हूँ"
 ], label=1.0 ), 
InputExample(texts=[ "My uncle is an executive engineer"
, "मेरे चाचाजी अधिशासी अभियंता हैं"
 ], label=1.0 ), 
InputExample(texts=[ "This is urgent work"
, "यह अत्यावश्यक कार्य है"
 ], label=1.0 ), 
InputExample(texts=[ "He's Pisces"
, "वह मीन राशि का है"
 ], label=1.0 ), 
InputExample(texts=[ "Sun will enter Aquarius at the end of this month"
, "इस महीने के अंत में सूर्य कुंभ राशि में प्रवेश कर जायेगा"
 ], label=1.0 ), 
InputExample(texts=[ "I want to know Capricorn's annual horoscope"
, "मुझे मकर राशि का वार्षिक भविष्यफल जानना है"
 ], label=1.0 ), 
InputExample(texts=[ "This month is fruitful for Sagittarius people"
, "यह माह धनु राशि वालों के लिए फलदायी है"
 ], label=1.0 ), 
InputExample(texts=[ "Scorpio is the sign of the zodiac"
, "वृश्चिक राशि का चिन्ह बिच्छू है"
 ], label=1.0 ), 
InputExample(texts=[ "The sign of Libra is the scales"
, "तुला राशि का चिन्ह तराजू है"
 ], label=1.0 ), 
InputExample(texts=[ "This year will prove fruitful for Virgo sign people"
, "यह वर्ष कन्या राशि के लोगों के लिए फलदायी सिद्ध होगा"
 ], label=1.0 ), 
InputExample(texts=[ "The Sun is currently in Leo"
, "इस समय सूर्य सिंह में है"
 ], label=1.0 ), 
InputExample(texts=[ "The sign of Cancer is the crab"
, "कर्क का चिन्ह केकड़ा है"
 ], label=1.0 ), 
InputExample(texts=[ "This year is favorable for Gemini people"
, "यह साल मिथुन राशि के लोगों के अनुकूल है"
 ], label=1.0 ), 
InputExample(texts=[ "The sign of Taurus is the bull"
, "वृष राशि का चिन्ह बैल है"
 ], label=1.0 ), 
InputExample(texts=[ "Her Zodiac Sign is Aries"
, "उसकी राशि मेष है"
 ], label=1.0 ), 
InputExample(texts=[ "Attach one attested copy of character certificate with the application form"
, "आवेदन पत्र के साथ चरित्र प्रमाण-पत्र की एक सत्यापित प्रतिलिपि संलग्न करें"
 ], label=1.0 ), 
InputExample(texts=[ "This application is unsigned"
, "यह आवेदन-पत्र अहस्ताक्षरित है"
 ], label=1.0 ), 
InputExample(texts=[ "My teeth are hard because of eating tamarind"
, "इमली खाने से मेरे दाँत कोठ हो गये हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Many types of tissues are found in the human body"
, "मानव शरीर में कई प्रकार के ऊतक पाये जाते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Gajshala clay is used in religious rituals"
, "गजशाला की मिट्टी का उपयोग धार्मिक अनुष्ठानों में किया जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "Duryodhana told Shri Krishna that without war, I will not give even land equal to the tip of a needle to the Pandavas."
, "दुर्योधन ने श्रीकृष्ण से कहा कि बिना युद्ध के सूई की नोक के बराबर ज़मीन भी पांडवों को नहीं दूँगा"
 ], label=1.0 ), 
InputExample(texts=[ "Shyaam is playing the flute"
, "श्याम बाँसुरी बजा रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam usually takes a bansi and goes towards the pond during the holidays"
, "छुट्टी के दिनों में श्याम प्रायः बंसी लेकर तालाब की ओर चला जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "The rod kept here is rusted"
, "यहाँ रखी छड़ में जंग लग गयी है"
 ], label=1.0 ), 
InputExample(texts=[ "There is a school near Shyam's house"
, "श्याम के घर के पास में एक विद्यालय है"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam has gone elsewhere with Ram"
, "श्याम राम के साथ अन्यत्र चला गया है"
 ], label=1.0 ), 
InputExample(texts=[ "The rise of the Mughal dynasty was at its zenith during the time of Akbar"
, "अकबर के समय में मुगल वंश का उत्थान अपने चरमोत्कर्ष पर था"
 ], label=1.0 ), 
InputExample(texts=[ "Nowadays dot is being used more as a full stop"
, "आजकल पूर्ण विराम के रूप में बिन्दी का प्रयोग ज्यादा हो रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "You put a full stop where you should put a semi-stop"
, "जहाँ अर्ध विराम लगाना चाहिए,वहाँ आपने पूर्ण विराम लगा दिया है"
 ], label=1.0 ), 
InputExample(texts=[ "In this sentence there should be a comma in place of and"
, "इस वाक्य में और की जगह पर अल्प विराम होना चाहिए"
 ], label=1.0 ), 
InputExample(texts=[ "Hey! You have come in the sentence there is an exclamation mark after Hey"
, "अरे! आप आ गए वाक्य में अरे के बाद विस्मयादि बोधक चिह्न लगा है"
 ], label=1.0 ), 
InputExample(texts=[ "The mark between the wealth and the property is an example of a adder"
, "धन-सम्पत्ति के बीच लगा चिह्न योजक चिह्न का उदाहरण है"
 ], label=1.0 ), 
InputExample(texts=[ "No quotation marks are used anywhere in this article"
, "इस लेख में कहीं भी उद्धरण चिन्ह का प्रयोग नहीं हुआ है"
 ], label=1.0 ), 
InputExample(texts=[ "Write these numbers inside brackets"
, "इन अंकों को कोष्टक चिह्न के अंदर लिखो"
 ], label=1.0 ), 
InputExample(texts=[ "[23(4)], it has an outer parenthesis, a large parenthesis"
, "[२३(४)], इसमें बाहरी कोष्टक, बड़ा कोष्टक चिन्ह है"
 ], label=1.0 ), 
InputExample(texts=[ "the child is dancing"
, "बच्चा फिरकी नचा रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "Many Indian kings fell with the invasion of the Mughals"
, "मुगलों के आक्रमण के साथ ही कई भारतीय राजाओं का पतन हो गया"
 ], label=1.0 ), 
InputExample(texts=[ "The speedometer of this vehicle is not working"
, "इस वाहन का गति मापक काम नहीं कर रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "The number of elements is stated to be twenty-five"
, "तत्त्वों की संख्या पच्चीस बताई गई है"
 ], label=1.0 ), 
InputExample(texts=[ "In a question containing parentheses, the parenthesis is removed after the middle bracket is removed"
, "कोष्टकवाले प्रश्न में मझला कोष्ठक हटाने के बाद छोटा कोष्ठक हटाया जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "(Mango), here is written mango in the middle of the parenthesis"
, "(आम), यहाँ छोटे कोष्टक के बीच में आम लिखा गया है"
 ], label=1.0 ), 
InputExample(texts=[ "There are many types of animal tissue"
, "जन्तु ऊतक कई प्रकार के होते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "In the bell of science, children were given information about vegetable tissue"
, "विज्ञान की घंटी में बच्चों को वनस्पति ऊतक के बारे में जानकारी दी गयी"
 ], label=1.0 ), 
InputExample(texts=[ "The flute is a great instrument"
, "बाँसुरी एक शुषिर वाद्य है"
 ], label=1.0 ), 
InputExample(texts=[ "Pandit Hariprasad Chaurasia won everyone's heart by playing the small flute"
, "पंडित हरिप्रसाद चौरसिया ने छोटी बाँसुरी बजाकर सबका दिल जीत लिया"
 ], label=1.0 ), 
InputExample(texts=[ "He is skilled in playing the Nakvanshi"
, "वह नकवंशी बजाने में निपुण है"
 ], label=1.0 ), 
InputExample(texts=[ "There are all kinds of instruments in this music school"
, "इस संगीत विद्यालय में हर प्रकार के वाद्ययंत्र हैं"
 ], label=1.0 ), 
InputExample(texts=[ "It measures a liter"
, "यह एक लीटर का मापक है"
 ], label=1.0 ), 
InputExample(texts=[ "Dhol is a percussion instrument"
, "ढोल एक थाप वाद्य है"
 ], label=1.0 ), 
InputExample(texts=[ "Manjira is a percussion instrument"
, "मँजीरा एक ताल वाद्य है"
 ], label=1.0 ), 
InputExample(texts=[ "The stringed instrument is a stringed instrument"
, "सारंगी एक तंतु वाद्य है"
 ], label=1.0 ), 
InputExample(texts=[ "He danced to the beat of the mridang"
, "मृदंग की ताल पर वह थिरक उठा"
 ], label=1.0 ), 
InputExample(texts=[ "When Ustad Zakir Hussain's fingers start tinkling on the tabla, the audience exclaims wah-wah"
, "जब उस्ताद ज़ाकिर हुसैन की अंगुलिया तबले पर थिरकने लगती हैं,तो श्रोता वाह-वाह कह उठता है"
 ], label=1.0 ), 
InputExample(texts=[ "The snake started shaking its head as soon as it played the bean"
, "बीन बजाते ही साँप अपना सिर हिलाने लगा"
 ], label=1.0 ), 
InputExample(texts=[ "Bhaskar is proficient in playing the violin"
, "भास्कर वायलिन बजाने में निपुण है"
 ], label=1.0 ), 
InputExample(texts=[ "Many pairs of cymbals were playing in the kirtan"
, "कीर्तन में कई जोड़े झाँझ बज रहे थे"
 ], label=1.0 ), 
InputExample(texts=[ "Yogi was good at playing the sarangi"
, "योगी सारंगी बजाने में मस्त था"
 ], label=1.0 ), 
InputExample(texts=[ "Deepak is proficient in playing the sitar"
, "दीपक सितार बजाने में निपुण है"
 ], label=1.0 ), 
InputExample(texts=[ "Mother Sharde where are you playing the veena"
, "माँ शारदे कहाँ तू वीणा बजा रही है"
 ], label=1.0 ), 
InputExample(texts=[ "Narasimha's voice is heard far and wide"
, "नरसिंहा की आवाज़ दूर-दूर तक सुनाई देती है"
 ], label=1.0 ), 
InputExample(texts=[ "I like to play the tanpura"
, "मुझे तानपूरा बजाना अच्छा लगता है"
 ], label=1.0 ), 
InputExample(texts=[ "He has gone to the hotel to eat kebabs"
, "वह होटल में कबाब खाने गया है"
 ], label=1.0 ), 
InputExample(texts=[ "Ravi, while playing the tabla, hit the left so hard that it exploded"
, "रवि ने तबला बजाते समय बायें पर इतने ज़ोर से मारा कि वह फूट गया"
 ], label=1.0 ), 
InputExample(texts=[ "The puris on both sides of this drum are spoiled"
, "इस ढोल के दोनों ओर की पूरियाँ खराब हो गयी हैं"
 ], label=1.0 ), 
InputExample(texts=[ "He was blowing the drum on the occasion of Idgah"
, "ईदगाह के अवसर पर वह ढक्का बजा रहा था"
 ], label=1.0 ), 
InputExample(texts=[ "The child stopped crying as soon as he saw the sip"
, "चुसनी देखते ही बच्चे ने रोना बंद कर दिया"
 ], label=1.0 ), 
InputExample(texts=[ "This cow has got a wound in one of the teats"
, "इस गाय की एक चूची में घाव हो गया है"
 ], label=1.0 ), 
InputExample(texts=[ "Amoeba divides into two parts to form a new amoeba"
, "अमीबा दो भागों में विभाजित होकर एक नया अमीबा तैयार करता है" 
 ], label=1.0 ), 
InputExample(texts=[ "Sumo wrestlers are very fat / obese people are at higher risk of heart disease"
, "सूमो पहलवान बहुत मोटे होते हैं / मोटे लोगों को हृदयरोग का खतरा अधिक होता है"
 ], label=1.0 ), 
InputExample(texts=[ "Amoebae are unicellular animals"
, "अमीबा एकोशिय जन्तु है"
 ], label=1.0 ), 
InputExample(texts=[ "Hydra is an invertebrate"
, "हाइड्रा एक अकशेरुकी जन्तु है"
 ], label=1.0 ), 
InputExample(texts=[ "Ramu is a bullshit person"
, "रामू एक बकवासी व्यक्ति है"
 ], label=1.0 ), 
InputExample(texts=[ "Even a balm got caught in a fisherman's net"
, "मछुआरे की जाल में एक बाम भी फँस गया"
 ], label=1.0 ), 
InputExample(texts=[ "I have a pain in my leg"
, "मेरे पैर में दर्द है"
 ], label=1.0 ), 
InputExample(texts=[ "He was bitten by a mad dog"
, "उसको एक पागल कुत्ते ने काट लिया"
 ], label=1.0 ), 
InputExample(texts=[ "We saw a monkey in the zoo"
, "हमने चिड़ियाघर में बनमानुस देखा"
 ], label=1.0 ), 
InputExample(texts=[ "mother's milk is the best food for babies"
, "बच्चों के लिए माँ का दूध सर्वोत्तम आहार है"
 ], label=1.0 ), 
InputExample(texts=[ "Cow is a herbivorous animal"
, "गाय एक शाकाहारी जंतु है"
 ], label=1.0 ), 
InputExample(texts=[ "The labor leader discussed with the workers during the work interval"
, "कार्य अंतराल में श्रमिक नेता ने श्रमिकों से विचार-विमर्श किया"
 ], label=1.0 ), 
InputExample(texts=[ "The whole table is blown up"
, "तबले की पूरी उधड़ गई है"
 ], label=1.0 ), 
InputExample(texts=[ "The water droplets on the padma leaf are shining like pearls in the sunlight"
, "पद्म-पत्र पर छिटके जलकण सूर्य-प्रकाश में मोती से चमक रहे हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Rose-berries are made from Mawa"
, "गुलाब-जामुन मावा से बनता है"
 ], label=1.0 ), 
InputExample(texts=[ "In the middle of the game I went out to have tea"
, "खेल के मध्यांतर में मैं चाय पीने चला गया"
 ], label=1.0 ), 
InputExample(texts=[ "There was Langar in the Gurudwara on the day of Gurupurnima"
, "गुरुपूर्णिमा के दिन गुरुद्वारे में लंगर था"
 ], label=1.0 ), 
InputExample(texts=[ "Gandhi Jayanti is celebrated with great pomp all over India on 2nd October"
, "दो अक्टूबर को पूरे भारत में गाँधी जयंती धूम-धाम से मनायी जाती है"
 ], label=1.0 ), 
InputExample(texts=[ "15 August is celebrated as Independence Day in India"
, "भारत में पन्द्रह अगस्त स्वतंत्रता दिवस के रूप में मनाया जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "Republic Day is celebrated with pomp every year"
, "गणतंत्र दिवस हर साल धूम-धाम से मनाया जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "We are going to Gurudwara to get langar"
, "हम लोग लंगर लेने गुरुद्वारा जा रहे हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Mother is making Baked Dal"
, "माँ बाकले की दाल बना रही है"
 ], label=1.0 ), 
InputExample(texts=[ "I couldn't see you due to busyness"
, "व्यस्तता के कारण मैं आपसे न मिल सका"
 ], label=1.0 ), 
InputExample(texts=[ "Mother is making bread for bread"
, "माँ चौरेठे की रोटी बना रही है"
 ], label=1.0 ), 
InputExample(texts=[ "Mother is making semolina pudding"
, "माँ सूजी का हलवा बना रही है"
 ], label=1.0 ), 
InputExample(texts=[ "He is eating plain dosa"
, "वह सादा डोसा खा रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "He ate four naans without hunger"
, "वह बिना भूख के चार नान खा गया"
 ], label=1.0 ), 
InputExample(texts=[ "He has planted a custard in his garden"
, "उसने अपने बगीचे में शरीफा लगा रखा है"
 ], label=1.0 ), 
InputExample(texts=[ "the child is eating biscuits"
, "बच्चा बिस्कुट खा रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "Due to incompetence, this work could not be done by Ramu"
, "अक्षमता के कारण रामू से यह कार्य न हो सका"
 ], label=1.0 ), 
InputExample(texts=[ "It was only because of your strength that this work could be done"
, "आपकी ताक़त के कारण ही यह कार्य हो सका"
 ], label=1.0 ), 
InputExample(texts=[ "Bacteriums of many diseases are found in unpolluted water"
, "अप्रवाहित जल में बहुत सारे रोगों के जीवाणु मिलते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "The germs of diseases cannot grow in flowing water"
, "प्रवाहित जल में रोगों के कीटाणु नहीं पनप पाते"
 ], label=1.0 ), 
InputExample(texts=[ "The snake sitting in the hollow of the tree was hissing"
, "पेड़ के खोखले भाग में बैठा सर्प फुफकार रहा था"
 ], label=1.0 ), 
InputExample(texts=[ "Shyam is cutting the cake on the occasion of his birthday"
, "श्याम अपने जन्मदिन के अवसर पर केक काट रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "He goes to the temple of God after taking a bath every day"
, "वह प्रतिदिन नहा-धोकर देव मंदिर जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "He goes to the temple after taking bath regularly"
, "वह नित्य नहा धोकर मंदिर जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "Harihar Das ji has built a grand Vishnu temple in his village"
, "हरिहर दास जी ने अपने गाँव में एक भव्य विष्णु मंदिर का निर्माण कराया है"
 ], label=1.0 ), 
InputExample(texts=[ "Shiva Linga is worshiped in India since ancient times"
, "पुरातन काल से भारत में शिव लिंग की पूजा की जाती है"
 ], label=1.0 ), 
InputExample(texts=[ "This Devi temple is the center of attraction for the devotees"
, "यह देवी मंदिर श्रद्धालुओं के आकर्षण का केंद्र है"
 ], label=1.0 ), 
InputExample(texts=[ "The Jain community has built a huge Jain temple in this city"
, "जैनी समुदाय ने इस शहर में एक विशाल जैन मंदिर का निर्माण कराया है"
 ], label=1.0 ), 
InputExample(texts=[ "He goes to the Parsi temple everyday"
, "वह प्रतिदिन पारसी मंदिर जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "Kushinagar has many Buddhist temples"
, "कुशीनगर में कई बौद्ध मंदिर हैं"
 ], label=1.0 ), 
InputExample(texts=[ "The sanctum sanctorum of this temple is very big"
, "इस मंदिर का गर्भ गृह बहुत बड़ा है"
 ], label=1.0 ), 
InputExample(texts=[ "Gujiyas are definitely made in our house in Holi"
, "हमारे घर होली में गुझिया ज़रूर बनाते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "confectioner is making pita"
, "हलवाई पेठा बना रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "He's Eating Balushahi"
, "वह बालूशाही खा रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "This Buddha Statue is Ashoka"
, "यह बुद्ध मूर्ति अशोककालीन है"
 ], label=1.0 ), 
InputExample(texts=[ "He makes any kind of idol"
, "वह किसी भी प्रकार की मूर्ति बना लेता है"
 ], label=1.0 ), 
InputExample(texts=[ "Netaji was sitting on the stage"
, "नेताजी मंच पर आसीन थे"
 ], label=1.0 ), 
InputExample(texts=[ "Idli is a South Indian dish"
, "इडली एक दक्षिण भारतीय व्यंजन है"
 ], label=1.0 ), 
InputExample(texts=[ "This is a Gupta stone statue"
, "यह गुप्तकालीन प्रस्तर मूर्ति है"
 ], label=1.0 ), 
InputExample(texts=[ "He is eating rasiyav and puri"
, "वह रसियाव और पूरी खा रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "This metal statue is very old"
, "यह धातु मूर्ति बहुत ही पुरानी है"
 ], label=1.0 ), 
InputExample(texts=[ "I was enjoying the play sitting close to the theater"
, "मैं रंगमंच के करीब बैठकर नाटक का आनंद ले रहा था"
 ], label=1.0 ), 
InputExample(texts=[ "Cow, buffalo etc. drive away insects and pests with their tail"
, "गाय,भैंस आदि पूँछ से कीड़े-मकोड़े भगाते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "Mother is making Basmati rice today"
, "माँ आज बासमती का भात बना रही है"
 ], label=1.0 ), 
InputExample(texts=[ "This saree is made of silk thread"
, "यह साड़ी रेशमी धागे से बनी हुई है"
 ], label=1.0 ), 
InputExample(texts=[ "Gold is a precious metal"
, "सोना एक कीमती धातु है"
 ], label=1.0 ), 
InputExample(texts=[ "The soil here is very fertile."
, "यहाँ की मिट्टी बहुत उपजाऊ है ।"
 ], label=1.0 ), 
InputExample(texts=[ "As soon as he touched the dog's body, he started wagging his tail"
, "कुत्ते के शरीर पर हाथ फेरते ही वह अपनी दुम हिलाने लगा"
 ], label=1.0 ), 
InputExample(texts=[ "Falsehood hides the truth"
, "बनावटीपन से असलियत छिप जाती है"
 ], label=1.0 ), 
InputExample(texts=[ "This fan is made of peacock tail"
, "यह पंखा मोर पूँछ से बना है"
 ], label=1.0 ), 
InputExample(texts=[ "The baby stopped crying after Sahlavan"
, "सहलावन के बाद बच्चे ने रोना बंद कर दिया"
 ], label=1.0 ), 
InputExample(texts=[ "It's Pure Mustard Oil"
, "यह शुद्ध सरसों का तेल है"
 ], label=1.0 ), 
InputExample(texts=[ "Ore is refined by chemical process"
, "अयस्क को रासायनिक प्रक्रिया द्वारा परिशुद्ध किया जाता है"
 ], label=1.0 ), 
InputExample(texts=[ "Gold is a precious metal"
, "सोना एक बहुमूल्य धातु है"
 ], label=1.0 ), 
InputExample(texts=[ "Aghani paddy is swaying in the fields"
, "खेतों में अगहनी धान लहलहा रही है"
 ], label=1.0 ), 
InputExample(texts=[ "Jesus had to go through many difficulties in his life"
, "अपने जीवन में ईसा को अनेक कठिनाइयों से गुजरना पड़ा"
 ], label=1.0 ), 
InputExample(texts=[ "Christians consider Jesus the messenger of God"
, "ईसाई लोग ईसा को भगवान का दूत मानते हैं"
 ], label=1.0 ), 
InputExample(texts=[ "This is a book of stories about Christ"
, "यह ईसा विषयक कहानियों की पुस्तक है"
 ], label=1.0 ), 
InputExample(texts=[ "The clergy have great importance in Christian society"
, "ईसाई समाज में पादरी का बड़ा महत्व है"
 ], label=1.0 ), 
InputExample(texts=[ "Your kurta has a broken button"
, "आपके कुर्ते का एक बटन टूट गया है"
 ], label=1.0 ), 
InputExample(texts=[ "He was walking with his caller"
, "वह कालर खड़ा करके चल रहा था"
 ], label=1.0 ), 
InputExample(texts=[ "The sleeve is the garment part"
, "आस्तिन परिधान भाग है"
 ], label=1.0 ), 
InputExample(texts=[ "Bhima had a lot of strength in his arms"
, "भीम की भुजाओं में बहुत बल था"
 ], label=1.0 ), 
InputExample(texts=[ "Today everyone is dressed in traditional dress in school"
, "आज विद्यालय में सब पारंपरिक पोशाक पहने हैं"
 ], label=1.0 ), 
InputExample(texts=[ "The saint-poets of Bhakti laid emphasis on the propagation of divine knowledge"
, "भक्तिकालीन संत कवियों ने ईश्वरीय ज्ञान के प्रचार-प्रसार पर बल दिया"
 ], label=1.0 ), 
InputExample(texts=[ "On hearing Guruji's inspirational words, he started reading diligently"
, "गुरुजी की प्रेरणादायक बातें सुनते ही वह मन लगाकर पढ़ने लगा"
 ], label=1.0 ), 
InputExample(texts=[ "The edge of this plate is too thin"
, "इस थाली का किनारा बहुत ही पतला है"
 ], label=1.0 ), 
InputExample(texts=[ "Christians were the originators of Christians"
, "ईसा ईसाइयों के धर्म प्रवर्तक थे"
 ], label=1.0 ), 
InputExample(texts=[ "Mahavir was the originator of Jainism"
, "महावीर जैन धर्म के प्रवर्तक थे"
 ], label=1.0 ), 
InputExample(texts=[ "The kids were clapping"
, "बच्चे ताली बजा रहे थे"
 ], label=1.0 ), 
InputExample(texts=[ "His eye is hurting because of being bilky"
, "बिलनी होने के कारण उसकी आँख में दर्द हो रहा है"
 ], label=1.0 ), 
InputExample(texts=[ "According to Vishnu Purana, Kamadeva was born as Pradyumna."
, "विष्णु पुराण के अनुसार कामदेव ही प्रद्युम्न के रूप में पैदा हुए थे"
 ], label=1.0 ), 
InputExample(texts=[ "Sometimes a meteorite is seen falling on the earth at night"
, "कभी-कभी रात में उल्काश्म पृथ्वी पर गिरता हुआ दिखाई देता है"
 ], label=1.0 ), 
InputExample(texts=[ "Corruption is rampant in the whole of this institution / His bitter words have set fire to my whole"
, "इस संस्थान के सर्वांग में भ्रष्टाचार व्याप्त है/उसके कटु वचन से मेरे सर्वांग में आग लग गयी"
 ], label=1.0 ), 
InputExample(texts=[ "The hand is an external body part"
, "हाथ एक बाह्य शारीरिक भाग है"
 ], label=1.0 ), 
InputExample(texts=[ "Ram grabbed my wrist"
, "राम ने मेरी कलाई पकड़ ली"
 ], label=1.0 ), 
InputExample(texts=[ "The fall has pierced his elbow"
, "गिरने से उसकी कुहनी छिल गयी है"
 ], label=1.0 ), 
InputExample(texts=[ "Two lignite mines unearthed in Bihar"
, "बिहार में लिग्नाइट की दो खानों का पता चला है"
 ], label=1.0 ), 
InputExample(texts=[ "She's cooking on charcoal"
, "वह लकड़ी के कोयले पर खाना बना रही है"
 ], label=1.0 ), 

]

# %%
#Define your train dataset, the dataloader and the train loss
train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=16)

# %%
from sentence_transformers import evaluation

# %%
train_loss = losses.CosineSimilarityLoss(model)

model_save_path= 'C:/Users/Omkar/Documents/Masters/temp.txt'

#Tune the model
model.fit(train_objectives=[(train_dataloader, train_loss)], output_path=model_save_path)
# Out:
# ...
# Iteration:   0%|          | 0/32 [00:00<?, ?it/s]

# %%
import os

# %%
print(os.getcwd())
# Out:
# /content
